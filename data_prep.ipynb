# %%
# !pip install pandas requests numpy scikit-learn
# Out:
# Requirement already satisfied: pandas in /opt/venv/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: requests in /opt/venv/lib/python3.11/site-packages (2.32.3)
# Requirement already satisfied: numpy in /opt/venv/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in /opt/venv/lib/python3.11/site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/venv/lib/python3.11/site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/venv/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/venv/lib/python3.11/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/venv/lib/python3.11/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/venv/lib/python3.11/site-packages (from requests) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/venv/lib/python3.11/site-packages (from requests) (2024.8.30)
# Requirement already satisfied: scipy>=1.6.0 in /opt/venv/lib/python3.11/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/venv/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/venv/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in /opt/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
from requests import get
import numpy as np
import re
import unicodedata
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

# %%
customers = pd.read_csv("data/customers_dataset.csv")
sellers = pd.read_csv("data/sellers_dataset.csv")
order_items = pd.read_csv("data/order_items_dataset.csv")
order_payments = pd.read_csv("data/order_payments_dataset.csv")
order_reviews = pd.read_csv("data/order_reviews_dataset.csv")
orders = pd.read_csv("data/orders_dataset.csv")
product_translation = pd.read_csv("data/product_category_name_translation.csv")
products = pd.read_csv("data/products_dataset.csv")
geolocations = pd.read_csv("data/geolocation_dataset.csv")

# %%
def save_encoder_data(label_encoder:LabelEncoder, save_path:str):
    data = dict(enumerate(label_encoder.classes_))
    dir = os.path.split(save_path)[0]
    if not os.path.isdir(dir):
        os.makedirs(dir, exist_ok=True)
    np.save(save_path, data)

# %%
def clean_text(input:str, only_normalize:bool):
    input = unicodedata.normalize("NFKD", input)
    input = "".join([c for c in input if not unicodedata.combining(c)])

    if not only_normalize:
        input = re.sub(r"^[0-9\*\.]+", "", input)
        input = re.sub(r"[^\w\s]", "", input)
        input = re.sub(r"\s+", " ", input)
        input = input.replace('-', '').strip().lower()

    return input

# %%
def getCoordinate(zip_code: int, geolocation_data: pd.DataFrame):
    result = geolocation_data[geolocation_data.geolocation_zip_code_prefix == zip_code][
        ["geolocation_lat", "geolocation_lng"]
    ]
    if len(result) == 0:
        closest_zip_code = (geolocation_data.geolocation_zip_code_prefix - 82040).abs()
        closest_zip_code_index = closest_zip_code.idxmin()
        closest_zip_code = geolocation_data.iloc[
            [closest_zip_code_index]
        ].geolocation_zip_code_prefix.values[0]
        result = (
            geolocation_data[
                geolocation_data.geolocation_zip_code_prefix == closest_zip_code
            ][["geolocation_lat", "geolocation_lng"]]
            .sample(frac=0.5)
            .mean()
            .to_frame()
            .T
        )
    else:
        result = result.sample(1)
    return result.iloc[0]

# %% [markdown]
# ## State's Abbreviation

# %%
state = pd.read_html(get("https://brazil-help.com/brazilian_states.htm").content)[2]
state.columns = state.iloc[1]
state = state.iloc[2:]
state = state[["Common Two Letter Abbreviation", "State"]]

state.State = state.State.apply(lambda x: clean_text(x, True))
state.sample(5, random_state=42)
# Out:
# 1  Common Two Letter Abbreviation     State
# 10                             GO     Goias
# 15                             PA      Para
# 11                             MA  Maranhao
# 23                             RO  Rondonia
# 2                              AC      Acre

# %%
customers.replace(dict(state.values), inplace=True)
sellers.replace(dict(state.values), inplace=True)
geolocations.replace(dict(state.values), inplace=True)

geolocations.sample(5, random_state=42)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 162456                         6412       -23.497836       -46.882982
# 65543                          3707       -23.507041       -46.543324
# 129566                         5406       -23.555752       -46.674463
# 999061                        99709       -27.661007       -52.285391
# 564558                        31310       -19.869566       -43.986149
#
#        geolocation_city  geolocation_state
# 162456          barueri          Sao Paulo
# 65543         sao paulo          Sao Paulo
# 129566        são paulo          Sao Paulo
# 999061          erechim  Rio Grande do Sul
# 564558   belo horizonte       Minas Gerais

# %% [markdown]
# ## Geolocation

# %%
geolocations.sample(5, random_state=42)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 162456                         6412       -23.497836       -46.882982
# 65543                          3707       -23.507041       -46.543324
# 129566                         5406       -23.555752       -46.674463
# 999061                        99709       -27.661007       -52.285391
# 564558                        31310       -19.869566       -43.986149
#
#        geolocation_city  geolocation_state
# 162456          barueri          Sao Paulo
# 65543         sao paulo          Sao Paulo
# 129566        são paulo          Sao Paulo
# 999061          erechim  Rio Grande do Sul
# 564558   belo horizonte       Minas Gerais

# %%
geolocations.dtypes
# Out:
# geolocation_zip_code_prefix      int64
# geolocation_lat                float64
# geolocation_lng                float64
# geolocation_city                object
# geolocation_state               object
# dtype: object

# %%
geolocations.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
geolocations.geolocation_city = geolocations.geolocation_city.apply(lambda x: clean_text(x, False))
geolocations.sample(5, random_state=42)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 162456                         6412       -23.497836       -46.882982
# 65543                          3707       -23.507041       -46.543324
# 129566                         5406       -23.555752       -46.674463
# 999061                        99709       -27.661007       -52.285391
# 564558                        31310       -19.869566       -43.986149
#
#        geolocation_city  geolocation_state
# 162456          barueri          Sao Paulo
# 65543         sao paulo          Sao Paulo
# 129566        sao paulo          Sao Paulo
# 999061          erechim  Rio Grande do Sul
# 564558   belo horizonte       Minas Gerais

# %%
city_encoder = LabelEncoder()
geolocations.geolocation_city = city_encoder.fit_transform(geolocations.geolocation_city)

save_encoder_data(city_encoder, "data/fix/city_encoder.npy")
dict(enumerate(city_encoder.classes_))
# Out:
# {0: 'abadia de goias',
#  1: 'abadia dos dourados',
#  2: 'abadiania',
#  3: 'abaete',
#  4: 'abaetetuba',
#  5: 'abaiara',
#  6: 'abaira',
#  7: 'abare',
#  8: 'abatia',
#  9: 'abdon batista',
#  10: 'abel figueiredo',
#  11: 'abelardo luz',
#  12: 'abrantes',
#  13: 'abre campo',
#  14: 'abreu e lima',
#  15: 'abreulandia',
#  16: 'abreus',
#  17: 'acaiaca',
#  18: 'acailandia',
#  19: 'acajutiba',
#  20: 'acara',
#  21: 'acarape',
#  22: 'acarau',
#  23: 'acari',
#  24: 'acaua',
#  25: 'acegua',
#  26: 'acioli',
#  27: 'acopiara',
#  28: 'acorizal',
#  29: 'acrelandia',
#  30: 'acreuna',
#  31: 'acu',
#  32: 'acu da torre',
#  33: 'acucena',
#  34: 'acupe',
#  35: 'adamantina',
#  36: 'adao colares',
#  37: 'adelandia',
#  38: 'adhemar de barros',
#  39: 'adolfo',
#  40: 'adrianopolis',
#  41: 'adustina',
#  42: 'afogados da ingazeira',
#  43: 'afonso arinos',
#  44: 'afonso bezerra',
#  45: 'afonso claudio',
#  46: 'afonso cunha',
#  47: 'afranio',
#  48: 'afua',
#  49: 'agisse',
#  50: 'agrestina',
#  51: 'agricolandia',
#  52: 'agrolandia',
#  53: 'agronomica',
#  54: 'agua azul do norte',
#  55: 'agua boa',
#  56: 'agua branca',
#  57: 'agua branca de minas',
#  58: 'agua clara',
#  59: 'agua comprida',
#  60: 'agua doce',
#  61: 'agua doce do maranhao',
#  62: 'agua doce do norte',
#  63: 'agua fria',
#  64: 'agua fria de goias',
#  65: 'agua limpa',
#  66: 'agua nova',
#  67: 'agua preta',
#  68: 'agua santa',
#  69: 'agua vermelha',
#  70: 'aguai',
#  71: 'aguanil',
#  72: 'aguas belas',
#  73: 'aguas claras',
#  74: 'aguas da prata',
#  75: 'aguas de chapeco',
#  76: 'aguas de lindoia',
#  77: 'aguas de santa barbara',
#  78: 'aguas de sao pedro',
#  79: 'aguas ferreas',
#  80: 'aguas formosas',
#  81: 'aguas frias',
#  82: 'aguas lindas de goias',
#  83: 'aguas mornas',
#  84: 'aguas vermelhas',
#  85: 'agudo',
#  86: 'agudos',
#  87: 'agudos do sul',
#  88: 'aguia branca',
#  89: 'aguiar',
#  90: 'aguiarnopolis',
#  91: 'agulha',
#  92: 'aimores',
#  93: 'aiquara',
#  94: 'aiuaba',
#  95: 'aiuruoca',
#  96: 'ajuricaba',
#  97: 'alagoa',
#  98: 'alagoa grande',
#  99: 'alagoa nova',
#  100: 'alagoinha',
#  101: 'alagoinha do piaui',
#  102: 'alagoinhas',
#  103: 'alambari',
#  104: 'albertina',
#  105: 'alberto isaacson',
#  106: 'alcantara',
#  107: 'alcantaras',
#  108: 'alcantil',
#  109: 'alcinopolis',
#  110: 'alcobaca',
#  111: 'aldeia',
#  112: 'aldeias altas',
#  113: 'alecrim',
#  114: 'alegre',
#  115: 'alegrete',
#  116: 'alegrete do piaui',
#  117: 'alegria',
#  118: 'alem paraiba',
#  119: 'alenquer',
#  120: 'alexandra',
#  121: 'alexandria',
#  122: 'alexandrita',
#  123: 'alexania',
#  124: 'alfenas',
#  125: 'alfredo chaves',
#  126: 'alfredo guedes',
#  127: 'alfredo marcondes',
#  128: 'alfredo vasconcelos',
#  129: 'alfredo wagner',
#  130: 'algodao de jandaira',
#  131: 'algodoes',
#  132: 'alhandra',
#  133: 'alianca',
#  134: 'alianca do tocantins',
#  135: 'almadina',
#  136: 'almas',
#  137: 'almeirim',
#  138: 'almenara',
#  139: 'almino afonso',
#  140: 'almirante tamandare',
#  141: 'almirante tamandare do sul',
#  142: 'aloandia',
#  143: 'alpercata',
#  144: 'alpestre',
#  145: 'alpinopolis',
#  146: 'alta alegre dos parecis',
#  147: 'alta floresta',
#  148: 'alta floresta do oeste',
#  149: 'alta floresta doeste',
#  150: 'altair',
#  151: 'altamira',
#  152: 'altamira do maranhao',
#  153: 'altamira do parana',
#  154: 'altaneira',
#  155: 'alterosa',
#  156: 'altinho',
#  157: 'altinopolis',
#  158: 'alto alegre',
#  159: 'alto alegre do iguacu',
#  160: 'alto alegre do maranhao',
#  161: 'alto alegre do pindare',
#  162: 'alto alegre dos parecis',
#  163: 'alto araguaia',
#  164: 'alto bela vista',
#  165: 'alto boa vista',
#  166: 'alto calcado',
#  167: 'alto caparao',
#  168: 'alto do rodrigues',
#  169: 'alto feliz',
#  170: 'alto garcas',
#  171: 'alto horizonte',
#  172: 'alto jequitiba',
#  173: 'alto longa',
#  174: 'alto maranhao',
#  175: 'alto mutum preto',
#  176: 'alto paraguai',
#  177: 'alto paraiso',
#  178: 'alto paraiso de goias',
#  179: 'alto parana',
#  180: 'alto parnaiba',
#  181: 'alto piquiri',
#  182: 'alto rio doce',
#  183: 'alto rio novo',
#  184: 'alto santo',
#  185: 'alto taquari',
#  186: 'altonia',
#  187: 'altos',
#  188: 'aluminio',
#  189: 'alvacao',
#  190: 'alvaraes',
#  191: 'alvarenga',
#  192: 'alvares florence',
#  193: 'alvares machado',
#  194: 'alvaro de carvalho',
#  195: 'alvinlandia',
#  196: 'alvinopolis',
#  197: 'alvorada',
#  198: 'alvorada de minas',
#  199: 'alvorada do gurgueia',
#  200: 'alvorada do norte',
#  201: 'alvorada do oeste',
#  202: 'alvorada do sul',
#  203: 'alvorada doeste',
#  204: 'amambai',
#  205: 'amanari',
#  206: 'amandina',
#  207: 'amanhece',
#  208: 'amapa',
#  209: 'amapa do maranhao',
#  210: 'amapari',
#  211: 'amapora',
#  212: 'amaraji',
#  213: 'amaral ferrador',
#  214: 'amaralina',
#  215: 'amarante',
#  216: 'amarante do maranhao',
#  217: 'amarantina',
#  218: 'amargosa',
#  219: 'amatura',
#  220: 'amelia rodrigues',
#  221: 'america dourada',
#  222: 'americana',
#  223: 'americano',
#  224: 'americano do brasil',
#  225: 'americo brasiliense',
#  226: 'americo de campos',
#  227: 'ametista do sul',
#  228: 'amontada',
#  229: 'amorinopolis',
#  230: 'amparo',
#  231: 'amparo da serra',
#  232: 'amparo de sao francisco',
#  233: 'ampere',
#  234: 'ana dias',
#  235: 'anadia',
#  236: 'anage',
#  237: 'anahy',
#  238: 'anajas',
#  239: 'anajatuba',
#  240: 'analandia',
#  241: 'anama',
#  242: 'ananas',
#  243: 'ananindeua',
#  244: 'anapolis',
#  245: 'anapu',
#  246: 'anapurus',
#  247: 'anastacio',
#  248: 'anaurilandia',
#  249: 'anchieta',
#  250: 'andarai',
#  251: 'andira',
#  252: 'andorinha',
#  253: 'andradas',
#  254: 'andrade pinto',
#  255: 'andradina',
#  256: 'andre da rocha',
#  257: 'andrelandia',
#  258: 'andrequice',
#  259: 'angatuba',
#  260: 'angelandia',
#  261: 'angelica',
#  262: 'angelim',
#  263: 'angelina',
#  264: 'angical',
#  265: 'angical do piaui',
#  266: 'angico',
#  267: 'angicos',
#  268: 'angra dos reis',
#  269: 'anguera',
#  270: 'anguereta',
#  271: 'angulo',
#  272: 'angustura',
#  273: 'anhandui',
#  274: 'anhanguera',
#  275: 'anhembi',
#  276: 'anhumas',
#  277: 'anicuns',
#  278: 'anisio de abreu',
#  279: 'anita garibaldi',
#  280: 'anitapolis',
#  281: 'anori',
#  282: 'anta',
#  283: 'anta gorda',
#  284: 'antas',
#  285: 'antonina',
#  286: 'antonina do norte',
#  287: 'antonio almeida',
#  288: 'antonio cardoso',
#  289: 'antonio carlos',
#  290: 'antonio dias',
#  291: 'antonio goncalves',
#  292: 'antonio joao',
#  293: 'antonio martins',
#  294: 'antonio olinto',
#  295: 'antonio pereira',
#  296: 'antonio prado',
#  297: 'antonio prado de minas',
#  298: 'antunes',
#  299: 'antunes igaratinga',
#  300: 'aparecida',
#  301: 'aparecida d oeste',
#  302: 'aparecida de goiania',
#  303: 'aparecida de minas',
#  304: 'aparecida de monte alto',
#  305: 'aparecida de sao manuel',
#  306: 'aparecida do rio doce',
#  307: 'aparecida do rio negro',
#  308: 'aparecida do taboado',
#  309: 'aparecida doeste',
#  310: 'aperibe',
#  311: 'apeu',
#  312: 'apiaca',
#  313: 'apiacas',
#  314: 'apiai',
#  315: 'apicumacu',
#  316: 'apiuna',
#  317: 'apodi',
#  318: 'apora',
#  319: 'apore',
#  320: 'apuarema',
#  321: 'apucarana',
#  322: 'apui',
#  323: 'apuiares',
#  324: 'aquidaba',
#  325: 'aquidaban',
#  326: 'aquidauana',
#  327: 'aquiraz',
#  328: 'arabuta',
#  329: 'aracagi',
#  330: 'aracai',
#  331: 'aracaju',
#  332: 'aracariguama',
#  333: 'aracas',
#  334: 'aracati',
#  335: 'aracatu',
#  336: 'aracatuba',
#  337: 'arace',
#  338: 'araci',
#  339: 'aracitaba',
#  340: 'aracoiaba',
#  341: 'aracoiaba da serra',
#  342: 'aracruz',
#  343: 'aracu',
#  344: 'aracuai',
#  345: 'aragarcas',
#  346: 'aragoiania',
#  347: 'aragominas',
#  348: 'araguacema',
#  349: 'araguacu',
#  350: 'araguaia',
#  351: 'araguaiana',
#  352: 'araguaina',
#  353: 'araguainha',
#  354: 'araguana',
#  355: 'araguapaz',
#  356: 'araguari',
#  357: 'araguatins',
#  358: 'araioses',
#  359: 'aral moreira',
#  360: 'aramari',
#  361: 'arambare',
#  362: 'arame',
#  363: 'aramina',
#  364: 'arandu',
#  365: 'arantina',
#  366: 'arapei',
#  367: 'arapiraca',
#  368: 'arapoema',
#  369: 'araponga',
#  370: 'arapongas',
#  371: 'arapora',
#  372: 'arapoti',
#  373: 'arapua',
#  374: 'araputanga',
#  375: 'araquari',
#  376: 'arara',
#  377: 'ararangua',
#  378: 'araraquara',
#  379: 'araras',
#  380: 'ararenda',
#  381: 'arari',
#  382: 'ararica',
#  383: 'araripe',
#  384: 'araripina',
#  385: 'araruama',
#  386: 'araruna',
#  387: 'arataca',
#  388: 'aratiba',
#  389: 'aratuba',
#  390: 'aratuipe',
#  391: 'araua',
#  392: 'araucaria',
#  393: 'araujos',
#  394: 'araxa',
#  395: 'arceburgo',
#  396: 'arco verde',
#  397: 'arcoiris',
#  398: 'arcos',
#  399: 'arcoverde',
#  400: 'areado',
#  401: 'areal',
#  402: 'arealva',
#  403: 'areia',
#  404: 'areia branca',
#  405: 'areia branca dos assis',
#  406: 'areia de baraunas',
#  407: 'areial',
#  408: 'areias',
#  409: 'areiopolis',
#  410: 'arembepe',
#  411: 'arenapolis',
#  412: 'arenopolis',
#  413: 'arez',
#  414: 'argirita',
#  415: 'aricanduva',
#  416: 'arinos',
#  417: 'aripuana',
#  418: 'ariquemes',
#  419: 'ariranha',
#  420: 'ariranha do ivai',
#  421: 'armacao de buzios',
#  422: 'armacao dos buzios',
#  423: 'armazem',
#  424: 'arneiroz',
#  425: 'aroazes',
#  426: 'aroeiras',
#  427: 'arraial',
#  428: 'arraial d ajuda',
#  429: 'arraial dajuda',
#  430: 'arraial do cabo',
#  431: 'arraias',
#  432: 'arroio do meio',
#  433: 'arroio do padre',
#  434: 'arroio do sal',
#  435: 'arroio do tigre',
#  436: 'arroio dos ratos',
#  437: 'arroio grande',
#  438: 'arroio trinta',
#  439: 'arrozal',
#  440: 'artur nogueira',
#  441: 'aruana',
#  442: 'aruja',
#  443: 'arvoredo',
#  444: 'arvorezinha',
#  445: 'ascurra',
#  446: 'aspasia',
#  447: 'assai',
#  448: 'assare',
#  449: 'assis',
#  450: 'assis brasil',
#  451: 'assis chateaubriand',
#  452: 'assuncao',
#  453: 'assuncao do piaui',
#  454: 'astolfo dutra',
#  455: 'astorga',
#  456: 'atalaia',
#  457: 'atalaia do norte',
#  458: 'atalanta',
#  459: 'ataleia',
#  460: 'atibaia',
#  461: 'atilio vivacqua',
#  462: 'augustinopolis',
#  463: 'augusto correa',
#  464: 'augusto de lima',
#  465: 'augusto pestana',
#  466: 'aurea',
#  467: 'aurelino leal',
#  468: 'auriflama',
#  469: 'aurilandia',
#  470: 'aurora',
#  471: 'aurora do iguacu',
#  472: 'aurora do para',
#  473: 'aurora do tocantins',
#  474: 'autazes',
#  475: 'avai',
#  476: 'avai do jacinto',
#  477: 'avanhandava',
#  478: 'avare',
#  479: 'avelar',
#  480: 'avelino lopes',
#  481: 'avelinopolis',
#  482: 'axixa',
#  483: 'axixa do tocantins',
#  484: 'azambuja',
#  485: 'azurita',
#  486: 'babaculandia',
#  487: 'bacabal',
#  488: 'bacabeira',
#  489: 'bacaxa',
#  490: 'bacaxa saquarema distrito',
#  491: 'bacuri',
#  492: 'bacurituba',
#  493: 'bady bassitt',
#  494: 'baependi',
#  495: 'bage',
#  496: 'bagre',
#  497: 'baguacu',
#  498: 'baguari',
#  499: 'baia formosa',
#  500: 'baianopolis',
#  501: 'baiao',
#  502: 'baixa grande',
#  503: 'baixa grande do ribeiro',
#  504: 'baixio',
#  505: 'baixo guandu',
#  506: 'balbinos',
#  507: 'baldim',
#  508: 'baliza',
#  509: 'balneario arroio do silva',
#  510: 'balneario barra do sul',
#  511: 'balneario camboriu',
#  512: 'balneario de picarras',
#  513: 'balneario gaivota',
#  514: 'balneario picarras',
#  515: 'balneario pinhal',
#  516: 'balneario rincao',
#  517: 'balsa nova',
#  518: 'balsamo',
#  519: 'balsas',
#  520: 'bambui',
#  521: 'banabuiu',
#  522: 'bananal',
#  523: 'bananeiras',
#  524: 'bandeira',
#  525: 'bandeira do sul',
#  526: 'bandeirante',
#  527: 'bandeirantes',
#  528: 'bandeirantes do tocantins',
#  529: 'bandeirantes doeste',
#  530: 'bannach',
#  531: 'banquete',
#  532: 'banzae',
#  533: 'barao',
#  534: 'barao ataliba nogueira',
#  535: 'barao de antonina',
#  536: 'barao de cocais',
#  537: 'barao de cotegipe',
#  538: 'barao de grajau',
#  539: 'barao de juparana',
#  540: 'barao de melgaco',
#  541: 'barao de monte alto',
#  542: 'barao do triunfo',
#  543: 'barauna',
#  544: 'barbacena',
#  545: 'barbalha',
#  546: 'barbosa',
#  547: 'barbosa ferraz',
#  548: 'barcarena',
#  549: 'barcelona',
#  550: 'barcelos',
#  551: 'bariri',
#  552: 'barra',
#  553: 'barra bonita',
#  554: 'barra da estiva',
#  555: 'barra dalcantara',
#  556: 'barra de guabiraba',
#  557: 'barra de santa rosa',
#  558: 'barra de santana',
#  559: 'barra de santo antonio',
#  560: 'barra de sao francisco',
#  561: 'barra de sao joao',
#  562: 'barra de sao miguel',
#  563: 'barra do ariranha',
#  564: 'barra do bugres',
#  565: 'barra do chapeu',
#  566: 'barra do choca',
#  567: 'barra do corda',
#  568: 'barra do cuiete',
#  569: 'barra do garcas',
#  570: 'barra do guarita',
#  571: 'barra do jacare',
#  572: 'barra do jacuipe',
#  573: 'barra do mendes',
#  574: 'barra do pirai',
#  575: 'barra do quarai',
#  576: 'barra do ribeiro',
#  577: 'barra do rio azul',
#  578: 'barra do rocha',
#  579: 'barra do tarrachil',
#  580: 'barra do turvo',
#  581: 'barra dos coqueiros',
#  582: 'barra feliz',
#  583: 'barra funda',
#  584: 'barra longa',
#  585: 'barra mansa',
#  586: 'barra velha',
#  587: 'barracao',
#  588: 'barrado quarai',
#  589: 'barras',
#  590: 'barreira',
#  591: 'barreiras',
#  592: 'barreiras do piaui',
#  593: 'barreirinhas',
#  594: 'barreiro branco',
#  595: 'barreiros',
#  596: 'barretos',
#  597: 'barrinha',
#  598: 'barro',
#  599: 'barro alto',
#  600: 'barro duro',
#  601: 'barro preto',
#  602: 'barrocas',
#  603: 'barrolandia',
#  604: 'barroquinha',
#  605: 'barros cassal',
#  606: 'barroso',
#  607: 'barueri',
#  608: 'bastos',
#  609: 'bataguassu',
#  610: 'bataipora',
#  611: 'batalha',
#  612: 'batatais',
#  613: 'batateira',
#  614: 'bataypora',
#  615: 'batinga',
#  616: 'baturite',
#  617: 'bauru',
#  618: 'bayeux',
#  619: 'bebedouro',
#  620: 'beberibe',
#  621: 'bela cruz',
#  622: 'bela vista',
#  623: 'bela vista da caroba',
#  624: 'bela vista de goias',
#  625: 'bela vista de minas',
#  626: 'bela vista do maranhao',
#  627: 'bela vista do paraiso',
#  628: 'bela vista do piaui',
#  629: 'bela vista do toldo',
#  630: 'belagua',
#  631: 'belem',
#  632: 'belem de maria',
#  633: 'belem de sao francisco',
#  634: 'belem do brejo do cruz',
#  635: 'belem do piaui',
#  636: 'belem do sao francisco',
#  637: 'belford roxo',
#  638: 'belmiro braga',
#  639: 'belmonte',
#  640: 'belo campo',
#  641: 'belo horizonta',
#  642: 'belo horizonte',
#  643: 'belo jardim',
#  644: 'belo oriente',
#  645: 'belo vale',
#  646: 'belterra',
#  647: 'beneditinos',
#  648: 'benedito leite',
#  649: 'benedito novo',
#  650: 'benevides',
#  651: 'benfica',
#  652: 'benjamin constant',
#  653: 'benjamin constant do sul',
#  654: 'bento de abreu',
#  655: 'bento fernandes',
#  656: 'bento goncalves',
#  657: 'bentopolis',
#  658: 'bentopolis de minas',
#  659: 'bequimao',
#  660: 'berilo',
#  661: 'berizal',
#  662: 'bernardino batista',
#  663: 'bernardino de campos',
#  664: 'bernardo do mearim',
#  665: 'bernardo sayao',
#  666: 'bertioga',
#  667: 'bertolinia',
#  668: 'bertopolis',
#  669: 'betania',
#  670: 'betania do piaui',
#  671: 'betim',
#  672: 'bezerros',
#  673: 'bh',
#  674: 'bias fortes',
#  675: 'bicas',
#  676: 'bicuiba',
#  677: 'biguacu',
#  678: 'bilac',
#  679: 'biquinhas',
#  680: 'birigui',
#  681: 'biritiba mirim',
#  682: 'biritibamirim',
#  683: 'biritinga',
#  684: 'bitupita',
#  685: 'bituruna',
#  686: 'bizarra',
#  687: 'blumenau',
#  688: 'boa esperanca',
#  689: 'boa esperanca do iguacu',
#  690: 'boa esperanca do sul',
#  691: 'boa hora',
#  692: 'boa nova',
#  693: 'boa saude',
#  694: 'boa sorte',
#  695: 'boa uniao',
#  696: 'boa uniao de itabirinha',
#  697: 'boa ventura',
#  698: 'boa ventura de sao roque',
#  699: 'boa viagem',
#  700: 'boa vista',
#  701: 'boa vista da aparecida',
#  702: 'boa vista das missoes',
#  703: 'boa vista de minas',
#  704: 'boa vista do burica',
#  705: 'boa vista do cadeado',
#  706: 'boa vista do gurupi',
#  707: 'boa vista do incra',
#  708: 'boa vista do ramos',
#  709: 'boa vista do sul',
#  710: 'boa vista do tupim',
#  711: 'boa vista dos andradas',
#  712: 'boca da mata',
#  713: 'boca do acre',
#  714: 'bocaina',
#  715: 'bocaina de minas',
#  716: 'bocaina do sul',
#  717: 'bocaiuva',
#  718: 'bocaiuva do sul',
#  719: 'bodo',
#  720: 'bodoco',
#  721: 'bodoquena',
#  722: 'bofete',
#  723: 'boituva',
#  724: 'bom conselho',
#  725: 'bom despacho',
#  726: 'bom fim do bom jesus',
#  727: 'bom jardim',
#  728: 'bom jardim da serra',
#  729: 'bom jardim de goias',
#  730: 'bom jardim de minas',
#  731: 'bom jardim do sul',
#  732: 'bom jesus',
#  733: 'bom jesus da lapa',
#  734: 'bom jesus da penha',
#  735: 'bom jesus da serra',
#  736: 'bom jesus das selvas',
#  737: 'bom jesus de goias',
#  738: 'bom jesus do amparo',
#  739: 'bom jesus do araguaia',
#  740: 'bom jesus do galho',
#  741: 'bom jesus do itabapoana',
#  742: 'bom jesus do norte',
#  743: 'bom jesus do sul',
#  744: 'bom jesus do tocantins',
#  745: 'bom jesus dos perdoes',
#  746: 'bom lugar',
#  747: 'bom principio',
#  748: 'bom principio do piaui',
#  749: 'bom progresso',
#  750: 'bom repouso',
#  751: 'bom retiro',
#  752: 'bom retiro da esperanca',
#  753: 'bom retiro do sul',
#  754: 'bom sucesso',
#  755: 'bom sucesso de itarare',
#  756: 'bom sucesso do sul',
#  757: 'bombinhas',
#  758: 'bonfim',
#  759: 'bonfim paulista',
#  760: 'bonfinopolis',
#  761: 'bonfinopolis de minas',
#  762: 'boninal',
#  763: 'bonito',
#  764: 'bonito de minas',
#  765: 'bonito de santa fe',
#  766: 'bonopolis',
#  767: 'boqueirao',
#  768: 'boqueirao do leao',
#  769: 'boqueirao do piaui',
#  770: 'boquim',
#  771: 'boquira',
#  772: 'boraceia',
#  773: 'borba',
#  774: 'borborema',
#  775: 'borda da mata',
#  776: 'borda do campo',
#  777: 'borebi',
#  778: 'borrazopolis',
#  779: 'bossoroca',
#  780: 'botelho',
#  781: 'botelhos',
#  782: 'botucatu',
#  783: 'botumirim',
#  784: 'botupora',
#  785: 'botuvera',
#  786: 'bozano',
#  787: 'braco do norte',
#  788: 'braco do rio',
#  789: 'braco do trombudo',
#  790: 'braga',
#  791: 'braganca',
#  792: 'braganca paulista',
#  793: 'braganey',
#  794: 'bragantina',
#  795: 'branquinha',
#  796: 'bras pires',
#  797: 'brasil novo',
#  798: 'brasilandia',
#  799: 'brasilandia de minas',
#  800: 'brasilandia do sul',
#  801: 'brasilandia do tocantins',
#  802: 'brasileia',
#  803: 'brasileira',
#  804: 'brasilia',
#  805: 'brasilia de minas',
#  806: 'brasitania',
#  807: 'brasnorte',
#  808: 'brasopolis',
#  809: 'brauna',
#  810: 'braunas',
#  811: 'brazabrantes',
#  812: 'brazlandia',
#  813: 'brazopolis',
#  814: 'brejao',
#  815: 'brejetuba',
#  816: 'brejinho',
#  817: 'brejinho de nazare',
#  818: 'brejo',
#  819: 'brejo alegre',
#  820: 'brejo bonito',
#  821: 'brejo da madre de deus',
#  822: 'brejo de areia',
#  823: 'brejo do cruz',
#  824: 'brejo do piaui',
#  825: 'brejo dos santos',
#  826: 'brejo grande',
#  827: 'brejo grande do araguaia',
#  828: 'brejo santo',
#  829: 'brejoes',
#  830: 'brejolandia',
#  831: 'breu branco',
#  832: 'breves',
#  833: 'britania',
#  834: 'brochier',
#  835: 'brodowski',
#  836: 'brotas',
#  837: 'brotas de macaubas',
#  838: 'brumadinho',
#  839: 'brumado',
#  840: 'brunopolis',
#  841: 'brusque',
#  842: 'bueno brandao',
#  843: 'buenopolis',
#  844: 'buenos aires',
#  845: 'buerarema',
#  846: 'bugre',
#  847: 'buique',
#  848: 'bujari',
#  849: 'bujaru',
#  850: 'burarama',
#  851: 'buri',
#  852: 'buritama',
#  853: 'buriti',
#  854: 'buriti alegre',
#  855: 'buriti bravo',
#  856: 'buriti de goias',
#  857: 'buriti do tocantins',
#  858: 'buriti dos lopes',
#  859: 'buriti dos montes',
#  860: 'buriticupu',
#  861: 'buritinopolis',
#  862: 'buritirama',
#  863: 'buritirana',
#  864: 'buritis',
#  865: 'buritizal',
#  866: 'buritizeiro',
#  867: 'butia',
#  868: 'buzios',
#  869: 'caapiranga',
#  870: 'caapora',
#  871: 'caarapo',
#  872: 'caatiba',
#  873: 'cabaceiras',
#  874: 'cabaceiras do paraguacu',
#  875: 'cabeceira grande',
#  876: 'cabeceiras',
#  877: 'cabeceiras do piaui',
#  878: 'cabedelo',
#  879: 'cabixi',
#  880: 'cabo de santo agostinho',
#  881: 'cabo frio',
#  882: 'cabo verde',
#  883: 'cabralia paulista',
#  884: 'cabreuva',
#  885: 'cabrobo',
#  886: 'cacador',
#  887: 'cacapava',
#  888: 'cacapava do sul',
#  889: 'cacaratiba',
#  890: 'cacarema',
#  891: 'cacaulandia',
#  892: 'cacequi',
#  893: 'caceres',
#  894: 'cachoeira',
#  895: 'cachoeira alegre',
#  896: 'cachoeira alta',
#  897: 'cachoeira da prata',
#  898: 'cachoeira de goias',
#  899: 'cachoeira de minas',
#  900: 'cachoeira de pajeu',
#  901: 'cachoeira de piria',
#  902: 'cachoeira de santa cruz',
#  903: 'cachoeira do arari',
#  904: 'cachoeira do brumado',
#  905: 'cachoeira do campo',
#  906: 'cachoeira do piria',
#  907: 'cachoeira do sul',
#  908: 'cachoeira dos indios',
#  909: 'cachoeira dourada',
#  910: 'cachoeira paulista',
#  911: 'cachoeiras de macacu',
#  912: 'cachoeirinha',
#  913: 'cachoeiro de itapemirim',
#  914: 'cacimba de dentro',
#  915: 'cacimbas',
#  916: 'cacimbinhas',
#  917: 'cacique doble',
#  918: 'cacoal',
#  919: 'caconde',
#  920: 'cacu',
#  921: 'cacule',
#  922: 'caem',
#  923: 'caetano mendes',
#  924: 'caetanopolis',
#  925: 'caetanos',
#  926: 'caete',
#  927: 'caetes',
#  928: 'caetite',
#  929: 'cafarnaum',
#  930: 'cafe',
#  931: 'cafeara',
#  932: 'cafelandia',
#  933: 'cafezal do sul',
#  934: 'caiabu',
#  935: 'caiana',
#  936: 'caiaponia',
#  937: 'caibate',
#  938: 'caibi',
#  939: 'caicara',
#  940: 'caicara do norte',
#  941: 'caicara do rio do vento',
#  942: 'caico',
#  943: 'caieiras',
#  944: 'cairu',
#  945: 'caiua',
#  946: 'cajamar',
#  947: 'cajapio',
#  948: 'cajari',
#  949: 'cajati',
#  950: 'cajazeiras',
#  951: 'cajazeiras do piaui',
#  952: 'cajobi',
#  953: 'cajueiro',
#  954: 'cajueiro da praia',
#  955: 'cajuri',
#  956: 'cajuru',
#  957: 'calcado',
#  958: 'calcoene',
#  959: 'caldas',
#  960: 'caldas brandao',
#  961: 'caldas novas',
#  962: 'caldazinha',
#  963: 'caldeirao grande',
#  964: 'caldeirao grande do piaui',
#  965: 'calheiros',
#  966: 'california',
#  967: 'california da barra',
#  968: 'california da barra barra do pirai',
#  969: 'calixto',
#  970: 'calmon',
#  971: 'calumbi',
#  972: 'camacan',
#  973: 'camacari',
#  974: 'camacho',
#  975: 'camalau',
#  976: 'camamu',
#  977: 'camanducaia',
#  978: 'camapua',
#  979: 'camaqua',
#  980: 'camaragibe',
#  981: 'camargo',
#  982: 'cambara',
#  983: 'cambara do sul',
#  984: 'cambe',
#  985: 'cambiasca',
#  986: 'cambira',
#  987: 'camboriu',
#  988: 'cambuci',
#  989: 'cambui',
#  990: 'cambuquira',
#  991: 'camela',
#  992: 'cameta',
#  993: 'camocim',
#  994: 'camocim de sao felix',
#  995: 'campanario',
#  996: 'campanha',
#  997: 'campestre',
#  998: 'campestre da serra',
#  999: 'campestre de goias',
#  ...}

# %%
state_encoder = LabelEncoder()
geolocations.geolocation_state = state_encoder.fit_transform(geolocations.geolocation_state)

save_encoder_data(state_encoder, "data/fix/state_encoder.npy")
dict(enumerate(state_encoder.classes_))
# Out:
# {0: 'Acre',
#  1: 'Alagoas',
#  2: 'Amapa',
#  3: 'Amazonas',
#  4: 'Bahia',
#  5: 'Ceara',
#  6: 'Distrito Federal',
#  7: 'Espirito Santo',
#  8: 'Goias',
#  9: 'Maranhao',
#  10: 'MatoGrosso',
#  11: 'MatoGrosso do Sul',
#  12: 'Minas Gerais',
#  13: 'Para',
#  14: 'Paraiba',
#  15: 'Parana',
#  16: 'Pernambuco',
#  17: 'Piaui',
#  18: 'Rio Grande do Norte',
#  19: 'Rio Grande do Sul',
#  20: 'Rio de Janeiro',
#  21: 'Rondonia',
#  22: 'Roraima',
#  23: 'Santa Catarina',
#  24: 'Sao Paulo',
#  25: 'Sergipe',
#  26: 'Tocantins'}

# %% [markdown]
# ## Product

# %%
products.sample(5, random_state=42)
# Out:
#                              product_id  product_category_name  \
# 24880  f819f0c84a64f02d3a5606ca95edd272     relogios_presentes
# 6366   b9de40e43fccb6ba53b7eadbd5c49077  utilidades_domesticas
# 4989   26afe4ed5890d941fcba14205863eec7       moveis_decoracao
# 8135   986870b9985d95ef6205bae1953a61a5       moveis_decoracao
# 19482  28ce57ecf4afba85e6020ec0209cada9             cool_stuff
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 24880                 59.0                       452.0                 1.0
# 6366                  41.0                      1188.0                 3.0
# 4989                  47.0                      1092.0                 1.0
# 8135                  50.0                       646.0                 1.0
# 19482                 31.0                       248.0                 2.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 24880             710.0               19.0               13.0
# 6366              700.0               70.0               10.0
# 4989             3850.0               30.0               30.0
# 8135              300.0               16.0               30.0
# 19482            5650.0               73.0               73.0
#
#        product_width_cm
# 24880              14.0
# 6366               15.0
# 4989               30.0
# 8135               20.0
# 19482              20.0

# %%
products.dtypes
# Out:
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %%
products.product_category_name = products.product_category_name.replace(dict(product_translation.values))
products.sample(5, random_state=42)
# Out:
#                              product_id product_category_name  \
# 24880  f819f0c84a64f02d3a5606ca95edd272         watches_gifts
# 6366   b9de40e43fccb6ba53b7eadbd5c49077            housewares
# 4989   26afe4ed5890d941fcba14205863eec7       furniture_decor
# 8135   986870b9985d95ef6205bae1953a61a5       furniture_decor
# 19482  28ce57ecf4afba85e6020ec0209cada9            cool_stuff
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 24880                 59.0                       452.0                 1.0
# 6366                  41.0                      1188.0                 3.0
# 4989                  47.0                      1092.0                 1.0
# 8135                  50.0                       646.0                 1.0
# 19482                 31.0                       248.0                 2.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 24880             710.0               19.0               13.0
# 6366              700.0               70.0               10.0
# 4989             3850.0               30.0               30.0
# 8135              300.0               16.0               30.0
# 19482            5650.0               73.0               73.0
#
#        product_width_cm
# 24880              14.0
# 6366               15.0
# 4989               30.0
# 8135               20.0
# 19482              20.0

# %%
products.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
product_category_name_encoder = LabelEncoder()
products.product_category_name = product_category_name_encoder.fit_transform(products.product_category_name)

save_encoder_data(product_category_name_encoder, "data/fix/product_category_name_encoder.npy")
dict(enumerate(product_category_name_encoder.classes_))
# Out:
# {0: 'agro_industry_and_commerce',
#  1: 'air_conditioning',
#  2: 'art',
#  3: 'arts_and_craftmanship',
#  4: 'audio',
#  5: 'auto',
#  6: 'baby',
#  7: 'bed_bath_table',
#  8: 'books_general_interest',
#  9: 'books_imported',
#  10: 'books_technical',
#  11: 'cds_dvds_musicals',
#  12: 'christmas_supplies',
#  13: 'cine_photo',
#  14: 'computers',
#  15: 'computers_accessories',
#  16: 'consoles_games',
#  17: 'construction_tools_construction',
#  18: 'construction_tools_lights',
#  19: 'construction_tools_safety',
#  20: 'cool_stuff',
#  21: 'costruction_tools_garden',
#  22: 'costruction_tools_tools',
#  23: 'diapers_and_hygiene',
#  24: 'drinks',
#  25: 'dvds_blu_ray',
#  26: 'electronics',
#  27: 'fashio_female_clothing',
#  28: 'fashion_bags_accessories',
#  29: 'fashion_childrens_clothes',
#  30: 'fashion_male_clothing',
#  31: 'fashion_shoes',
#  32: 'fashion_sport',
#  33: 'fashion_underwear_beach',
#  34: 'fixed_telephony',
#  35: 'flowers',
#  36: 'food',
#  37: 'food_drink',
#  38: 'furniture_bedroom',
#  39: 'furniture_decor',
#  40: 'furniture_living_room',
#  41: 'furniture_mattress_and_upholstery',
#  42: 'garden_tools',
#  43: 'health_beauty',
#  44: 'home_appliances',
#  45: 'home_appliances_2',
#  46: 'home_comfort_2',
#  47: 'home_confort',
#  48: 'home_construction',
#  49: 'housewares',
#  50: 'industry_commerce_and_business',
#  51: 'kitchen_dining_laundry_garden_furniture',
#  52: 'la_cuisine',
#  53: 'luggage_accessories',
#  54: 'market_place',
#  55: 'music',
#  56: 'musical_instruments',
#  57: 'office_furniture',
#  58: 'party_supplies',
#  59: 'pc_gamer',
#  60: 'perfumery',
#  61: 'pet_shop',
#  62: 'portateis_cozinha_e_preparadores_de_alimentos',
#  63: 'security_and_services',
#  64: 'signaling_and_security',
#  65: 'small_appliances',
#  66: 'small_appliances_home_oven_and_coffee',
#  67: 'sports_leisure',
#  68: 'stationery',
#  69: 'tablets_printing_image',
#  70: 'telephony',
#  71: 'toys',
#  72: 'watches_gifts',
#  73: nan}

# %%
products.product_category_name = products.product_category_name.replace({73: np.nan})
products = products.interpolate("linear")

products[
    [
        "product_category_name",
        "product_name_lenght",
        "product_description_lenght",
        "product_photos_qty",
    ]
] = products[
    [
        "product_category_name",
        "product_name_lenght",
        "product_description_lenght",
        "product_photos_qty",
    ]
].astype(
    int
)

products.sample(5, random_state=42)
# Out:
# /tmp/ipykernel_51721/593171292.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   products = products.interpolate("linear")
#                              product_id  product_category_name  \
# 24880  f819f0c84a64f02d3a5606ca95edd272                     72
# 6366   b9de40e43fccb6ba53b7eadbd5c49077                     49
# 4989   26afe4ed5890d941fcba14205863eec7                     39
# 8135   986870b9985d95ef6205bae1953a61a5                     39
# 19482  28ce57ecf4afba85e6020ec0209cada9                     20
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 24880                   59                         452                   1
# 6366                    41                        1188                   3
# 4989                    47                        1092                   1
# 8135                    50                         646                   1
# 19482                   31                         248                   2
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 24880             710.0               19.0               13.0
# 6366              700.0               70.0               10.0
# 4989             3850.0               30.0               30.0
# 8135              300.0               16.0               30.0
# 19482            5650.0               73.0               73.0
#
#        product_width_cm
# 24880              14.0
# 6366               15.0
# 4989               30.0
# 8135               20.0
# 19482              20.0

# %%
products.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# ## Orders

# %%
orders.sample(5, random_state=42)
# Out:
#                                order_id                       customer_id  \
# 52263  b9a6c5f5df52c7226ac85aee7524c27f  f160aaf480efdfa7268f0fa535f73e76
# 46645  261e71d2349c713eafa9f3df5972b95d  d6708bbbd2d419475869a84e41f620a1
# 37546  67b50899f52995848c427e361e10dde3  1b353c00c71689afba44554e43cc5a76
# 94756  32733fc014b67ef70fa6039dd8c6ba82  ad66699beab381d0747605f108cc02b4
# 14771  39a70e9e9b729b11dee34ac12478597f  20c678bfce3c8252288f70dd2bee5e51
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 52263    delivered      2018-06-12 20:07:44  2018-06-12 20:44:26
# 46645    delivered      2018-01-20 12:15:57  2018-01-20 12:37:13
# 37546    delivered      2018-06-16 21:24:10  2018-06-16 21:36:59
# 94756    delivered      2017-08-30 21:12:28  2017-08-31 02:50:24
# 14771    delivered      2017-08-10 21:26:25  2017-08-10 21:44:13
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 52263          2018-06-13 13:09:00           2018-06-19 12:44:08
# 46645          2018-01-25 21:42:52           2018-01-30 11:32:35
# 37546          2018-06-21 13:55:00           2018-06-27 13:17:27
# 94756          2017-09-12 20:16:46           2017-09-25 17:53:23
# 14771          2017-08-11 19:11:16           2017-08-22 16:45:00
#
#       order_estimated_delivery_date
# 52263           2018-07-17 00:00:00
# 46645           2018-02-15 00:00:00
# 37546           2018-07-16 00:00:00
# 94756           2017-09-22 00:00:00
# 14771           2017-09-12 00:00:00

# %%
orders.dtypes
# Out:
# order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object

# %%
datetime_columns = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date",
]
for i in datetime_columns:
    orders[i] = pd.to_datetime(orders[i])

orders.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
orders.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
order_status_encoder = LabelEncoder()
orders.order_status = order_status_encoder.fit_transform(orders.order_status)

save_encoder_data(order_status_encoder, "data/fix/order_status_encoder.npy")
dict(enumerate(order_status_encoder.classes_))
# Out:
# {0: 'approved',
#  1: 'canceled',
#  2: 'created',
#  3: 'delivered',
#  4: 'invoiced',
#  5: 'processing',
#  6: 'shipped',
#  7: 'unavailable'}

# %%
orders.interpolate("linear", inplace=True)

orders.isna().sum()
# Out:
# /tmp/ipykernel_51721/856102165.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   orders.interpolate("linear", inplace=True)
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# ## Order Items

# %%
order_items.sample(5, random_state=42)
# Out:
#                                 order_id  order_item_id  \
# 107777  f4ee4273538924bda6212f5948e80fde              1
# 2391    056349f85a73d794119c4286c95a52de              1
# 77829   b124967afcc82ef17ec41020fe2a9136              1
# 99819   e257ae8610fb4fb68a1f459c3a4b1f51              1
# 41297   5e114d8e3840661abc3d9c4820f427b3              1
#
#                               product_id                         seller_id  \
# 107777  69455f41626a745aea9ee9164cb9eafd  7d13fca15225358621be4086e1eb0964
# 2391    af35be35db4ad0dc288b571453337376  d20b021d3efdf267a402c402a48ea64b
# 77829   12e6d0f655986ceff00c74658dec97b1  3be634553519fb6536a03e1358e9fdc7
# 99819   a50acd33ba7a8da8e9db65094fa990a4  8581055ce74af1daba164fdbd55a40de
# 41297   5cca3efb9521cc1d7099d610d4a12017  3d871de0142ce09b7081e2b9d1733cb1
#
#         shipping_limit_date   price  freight_value
# 107777  2018-06-19 09:18:15  180.00          20.45
# 2391    2017-03-09 14:35:09   10.99          16.05
# 77829   2018-06-06 17:18:09   49.99           8.88
# 99819   2017-05-18 08:02:19  117.30          14.43
# 41297   2018-05-03 18:15:09   58.90          13.77

# %%
order_items.dtypes
# Out:
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object

# %%
datetime_columns = [
    "shipping_limit_date"
]
for i in datetime_columns:
    order_items[i] = pd.to_datetime(order_items[i])

order_items.dtypes
# Out:
# order_id                       object
# order_item_id                   int64
# product_id                     object
# seller_id                      object
# shipping_limit_date    datetime64[ns]
# price                         float64
# freight_value                 float64
# dtype: object

# %%
order_items.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %% [markdown]
# ## Order Payments

# %%
order_payments.sample(5, random_state=42)
# Out:
#                                order_id  payment_sequential payment_type  \
# 21856  61c7b1cf28b58654fe411aaf87fe249d                   1   debit_card
# 82913  a01f943f4a95572159f0603bd160d67a                   1  credit_card
# 81375  267968a4442f2e55c2904cac31c26660                   1  credit_card
# 9274   303c1a4cb953c69bf9ad12194dc3d44d                   1  credit_card
# 77826  c5f5087eaff455f93653900411e34432                   1       boleto
#
#        payment_installments  payment_value
# 21856                     1          39.60
# 82913                     1         111.42
# 81375                     1          37.37
# 9274                      1          47.96
# 77826                     1         141.88

# %%
order_payments.dtypes
# Out:
# order_id                 object
# payment_sequential        int64
# payment_type             object
# payment_installments      int64
# payment_value           float64
# dtype: object

# %%
order_payments.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
payment_type_encoder = LabelEncoder()
order_payments.payment_type = payment_type_encoder.fit_transform(order_payments.payment_type)

save_encoder_data(payment_type_encoder, "data/fix/payment_type_encoder.npy")
dict(enumerate(payment_type_encoder.classes_))
# Out:
# {0: 'boleto',
#  1: 'credit_card',
#  2: 'debit_card',
#  3: 'not_defined',
#  4: 'voucher'}

# %% [markdown]
# ## Order Reviews

# %%
order_reviews.sample(5, random_state=42)
# Out:
#                               review_id                          order_id  \
# 90252  406e32984dd5273582105460a79571af  e00ed9d20c3479f9f0e9727ca9d60946
# 24436  3bca8d9922bed47eb96f23d121945290  3b5351f5f99b46339212291661a9d226
# 11313  65895b807ac5dfe062c82400b3f210b8  f395e98fb5c1c6ce1306e80de2fe125b
# 75442  2a6faa65a6e893105c60b1018d40e14a  57899333b5e286632bd2599d3f7864ce
# 7217   a738aa683a09dc5979abc7d9c2cc8029  0cc76fbe09687fda664178e9fc6c404f
#
#        review_score review_comment_title review_comment_message  \
# 90252             5                  NaN                    NaN
# 24436             5                  NaN    Cumpriu o acordado!
# 11313             4                  NaN                    NaN
# 75442             5                  NaN                    NaN
# 7217              5                  NaN                    NaN
#
#       review_creation_date review_answer_timestamp
# 90252  2017-12-22 00:00:00     2017-12-22 21:10:19
# 24436  2018-04-10 00:00:00     2018-04-13 01:57:05
# 11313  2017-04-20 00:00:00     2017-04-21 11:31:32
# 75442  2018-04-06 00:00:00     2018-04-07 00:34:14
# 7217   2018-01-07 00:00:00     2018-01-08 13:48:20

# %%
order_reviews.dtypes
# Out:
# review_id                  object
# order_id                   object
# review_score                int64
# review_comment_title       object
# review_comment_message     object
# review_creation_date       object
# review_answer_timestamp    object
# dtype: object

# %%
datetime_columns = [
    "review_creation_date",
    "review_answer_timestamp",
]
for i in datetime_columns:
    order_reviews[i] = pd.to_datetime(order_reviews[i])

order_reviews.dtypes
# Out:
# review_id                          object
# order_id                           object
# review_score                        int64
# review_comment_title               object
# review_comment_message             object
# review_creation_date       datetime64[ns]
# review_answer_timestamp    datetime64[ns]
# dtype: object

# %%
order_reviews.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %% [markdown]
# ## Customers

# %%
customers.sample(5, random_state=42)
# Out:
#                             customer_id                customer_unique_id  \
# 52263  c7432c6d237ffd6aa36a007b4237ec38  9a897ea48bf988012c00b802f1104a92
# 46645  7f399d641e2e2064470145178c9e8778  90436a67885a57f147fb79e6d0e4bc1c
# 37546  ba5642b730704dc0f74b7cf715b41ed5  4d8056f71519ae1069e6747c63c676f7
# 94756  0f346a2cc84ebb2d52f0759d0acfd030  6117c9ef3251089693a6abb90c195eba
# 14771  d393b9491df482cf448e60aa9955b7f2  5caf3a2a5d1ef808e3dd182e79baa392
#
#        customer_zip_code_prefix    customer_city  customer_state
# 52263                      2971        sao paulo       Sao Paulo
# 46645                     38610             unai    Minas Gerais
# 37546                     88820            icara  Santa Catarina
# 94756                     25250  duque de caxias  Rio de Janeiro
# 14771                     36955            mutum    Minas Gerais

# %%
customers.dtypes
# Out:
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object

# %%
customers.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customers.drop(columns=["customer_city","customer_state"], inplace=True)
customers.sample(5, random_state=42)
# Out:
#                             customer_id                customer_unique_id  \
# 52263  c7432c6d237ffd6aa36a007b4237ec38  9a897ea48bf988012c00b802f1104a92
# 46645  7f399d641e2e2064470145178c9e8778  90436a67885a57f147fb79e6d0e4bc1c
# 37546  ba5642b730704dc0f74b7cf715b41ed5  4d8056f71519ae1069e6747c63c676f7
# 94756  0f346a2cc84ebb2d52f0759d0acfd030  6117c9ef3251089693a6abb90c195eba
# 14771  d393b9491df482cf448e60aa9955b7f2  5caf3a2a5d1ef808e3dd182e79baa392
#
#        customer_zip_code_prefix
# 52263                      2971
# 46645                     38610
# 37546                     88820
# 94756                     25250
# 14771                     36955

# %%
customers[["customer_geolocation_lat", "customer_geolocation_lng"]] = (
    customers.customer_zip_code_prefix.apply(lambda x: getCoordinate(x, geolocations))
)
customers.sample(5, random_state=42)
# Out:
#                             customer_id                customer_unique_id  \
# 52263  c7432c6d237ffd6aa36a007b4237ec38  9a897ea48bf988012c00b802f1104a92
# 46645  7f399d641e2e2064470145178c9e8778  90436a67885a57f147fb79e6d0e4bc1c
# 37546  ba5642b730704dc0f74b7cf715b41ed5  4d8056f71519ae1069e6747c63c676f7
# 94756  0f346a2cc84ebb2d52f0759d0acfd030  6117c9ef3251089693a6abb90c195eba
# 14771  d393b9491df482cf448e60aa9955b7f2  5caf3a2a5d1ef808e3dd182e79baa392
#
#        customer_zip_code_prefix  customer_geolocation_lat  \
# 52263                      2971                -23.481629
# 46645                     38610                -16.368648
# 37546                     88820                -28.699661
# 94756                     25250                -22.607244
# 14771                     36955                -19.821216
#
#        customer_geolocation_lng
# 52263                -46.712144
# 46645                -46.898484
# 37546                -49.304257
# 94756                -43.314948
# 14771                -41.445674

# %%
customers.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_geolocation_lat    0
# customer_geolocation_lng    0
# dtype: int64

# %% [markdown]
# # Seller

# %%
sellers.sample(5, random_state=42)
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 1947  1f7fd2a6fcd5a6fa5d8a4dabc72aaae0                   95800
# 1309  6e1862e15f33d9994bc25922a85e1efc                   13505
# 1606  e628d4a53c109f09ca88098338b3a3f5                   30170
# 2626  0249d282d911d23cb8b869ab49c99f53                    5676
# 2440  bdae679a9b282249bc23b9b69dae9a99                   72210
#
#          seller_city       seller_state
# 1947  venancio aires  Rio Grande do Sul
# 1309       rio claro          Sao Paulo
# 1606  belo horizonte       Minas Gerais
# 2626       sao paulo          Sao Paulo
# 2440        brasilia   Distrito Federal

# %%
sellers.dtypes
# Out:
# seller_id                 object
# seller_zip_code_prefix     int64
# seller_city               object
# seller_state              object
# dtype: object

# %%
sellers.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
sellers.drop(columns=["seller_city","seller_state"], inplace=True)
sellers.sample(5, random_state=42)
# Out:
#                              seller_id  seller_zip_code_prefix
# 1947  1f7fd2a6fcd5a6fa5d8a4dabc72aaae0                   95800
# 1309  6e1862e15f33d9994bc25922a85e1efc                   13505
# 1606  e628d4a53c109f09ca88098338b3a3f5                   30170
# 2626  0249d282d911d23cb8b869ab49c99f53                    5676
# 2440  bdae679a9b282249bc23b9b69dae9a99                   72210

# %%
sellers[["seller_geolocation_lat", "seller_geolocation_lng"]] = (
    sellers.seller_zip_code_prefix.apply(lambda x: getCoordinate(x, geolocations))
)
sellers.sample(5, random_state=42)
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 1947  1f7fd2a6fcd5a6fa5d8a4dabc72aaae0                   95800
# 1309  6e1862e15f33d9994bc25922a85e1efc                   13505
# 1606  e628d4a53c109f09ca88098338b3a3f5                   30170
# 2626  0249d282d911d23cb8b869ab49c99f53                    5676
# 2440  bdae679a9b282249bc23b9b69dae9a99                   72210
#
#       seller_geolocation_lat  seller_geolocation_lng
# 1947              -29.572522              -52.158738
# 1309              -22.380729              -47.556773
# 1606              -19.933980              -43.944004
# 2626              -23.596003              -46.698785
# 2440              -15.804566              -48.107983

# %%
sellers.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_geolocation_lat    0
# seller_geolocation_lng    0
# dtype: int64

# %% [markdown]
# # Assambling Data

# %%
detailed_orders_data = order_items.merge(orders, on='order_id') \
                    .merge(order_payments, on='order_id') \
                    .merge(products, on='product_id') \
                    .merge(customers, on='customer_id') \
                    .merge(sellers, on='seller_id')

detailed_orders_data.sample(5, random_state=42)
# Out:
#                                 order_id  order_item_id  \
# 49672   6bd41909d90c9f91e22ad236ea395623              1
# 23948   344c86e9cc82d497519e09dc351d28ff              1
# 105553  e55e4860fd8e46e38f351f994f9e06cb              1
# 68942   96bac00ebfd18ba64dabd7cb27471282              1
# 80847   b02fefc3800702d58c988da39c132902              1
#
#                               product_id                         seller_id  \
# 49672   c5e9b73e5f4c644885862ba3e1137b57  46dc3b2cc0980fb8ec44634e21d2718e
# 23948   b5e13c9a353102f79c6206ff5cb61a50  a49928bcdf77c55c6d6e05e09a9b4ca5
# 105553  3a7c9b0413d7b9cc7f4a18318fc5afb3  7a67c85e85bb2ce8582c35f2203ad736
# 68942   5411e9269501a870cabf632f05655131  3d871de0142ce09b7081e2b9d1733cb1
# 80847   144266e1585320d057797a369596bb8b  8cc6a0e5738e61a87b03c78b2ba9db4b
#
#        shipping_limit_date   price  freight_value  \
# 49672  2017-10-09 16:49:50  199.99          16.16
# 23948  2017-11-17 11:55:30   89.90          11.83
# 105553 2017-03-16 01:19:21  129.99           9.28
# 68942  2018-01-19 10:32:21  129.00          38.45
# 80847  2017-03-28 10:44:34  739.90          21.92
#
#                              customer_id  order_status  \
# 49672   f45ac6dfd34f67fc16e581fe9ae0028e             3
# 23948   d5b301a2087b017c4a9ca9730a2b18cf             3
# 105553  676ee955ce60a3b6eaa8c816cfb7fb04             3
# 68942   2f7319232811fe9879212e93efb30147             3
# 80847   374d1a370cc4fc67244345f046bbdff6             3
#
#        order_purchase_timestamp  ... product_length_cm product_height_cm  \
# 49672       2017-10-03 16:41:47  ...              29.0              11.0
# 23948       2017-11-12 11:43:17  ...              40.0              25.0
# 105553      2017-03-12 01:19:21  ...              50.0              40.0
# 68942       2018-01-09 19:34:58  ...              38.0              30.0
# 80847       2017-03-22 10:44:34  ...              30.0              32.0
#
#        product_width_cm                customer_unique_id  \
# 49672              28.0  98407dc3f7283a8a678d1d97e139bce9
# 23948              20.0  45167dabf29a055f7c1208a69dc95586
# 105553             30.0  b21b70ecf581fa5addd602adc787d832
# 68942              28.0  adc2b0515dd6bea5e28161bbfeeade0e
# 80847              27.0  b4891a8e1c6726d478568eb2422dcce9
#
#         customer_zip_code_prefix  customer_geolocation_lat  \
# 49672                      71931                -15.836123
# 23948                       8210                -23.532594
# 105553                      8111                -23.488042
# 68942                      58045                 -7.123182
# 80847                       6708                -23.585222
#
#         customer_geolocation_lng  seller_zip_code_prefix  \
# 49672                 -48.040185                   22240
# 23948                 -46.442789                    3017
# 105553                -46.376701                    3426
# 68942                 -34.828699                   13232
# 80847                 -46.849074                   37795
#
#         seller_geolocation_lat  seller_geolocation_lng
# 49672               -22.932957              -43.187386
# 23948               -23.533704              -46.612530
# 105553              -23.554792              -46.531428
# 68942               -23.209964              -46.776231
# 80847               -22.087304              -46.581748
#
# [5 rows x 33 columns]

# %%
from math import radians, sin, cos, sqrt, atan2


def haversine(data:pd.Series):
    R = 6371.0

    lat1, lon1, lat2, lon2 = map(radians, data.values)

    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlon / 2) ** 2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return round(distance, 2)

detailed_orders_data["seller_customer_distance_km"] = detailed_orders_data[
    [
        "customer_geolocation_lat",
        "customer_geolocation_lng",
        "seller_geolocation_lat",
        "seller_geolocation_lng",
    ]
].agg(haversine, axis=1)

detailed_orders_data.sample(5, random_state=42)
# Out:
#                                 order_id  order_item_id  \
# 49672   6bd41909d90c9f91e22ad236ea395623              1
# 23948   344c86e9cc82d497519e09dc351d28ff              1
# 105553  e55e4860fd8e46e38f351f994f9e06cb              1
# 68942   96bac00ebfd18ba64dabd7cb27471282              1
# 80847   b02fefc3800702d58c988da39c132902              1
#
#                               product_id                         seller_id  \
# 49672   c5e9b73e5f4c644885862ba3e1137b57  46dc3b2cc0980fb8ec44634e21d2718e
# 23948   b5e13c9a353102f79c6206ff5cb61a50  a49928bcdf77c55c6d6e05e09a9b4ca5
# 105553  3a7c9b0413d7b9cc7f4a18318fc5afb3  7a67c85e85bb2ce8582c35f2203ad736
# 68942   5411e9269501a870cabf632f05655131  3d871de0142ce09b7081e2b9d1733cb1
# 80847   144266e1585320d057797a369596bb8b  8cc6a0e5738e61a87b03c78b2ba9db4b
#
#        shipping_limit_date   price  freight_value  \
# 49672  2017-10-09 16:49:50  199.99          16.16
# 23948  2017-11-17 11:55:30   89.90          11.83
# 105553 2017-03-16 01:19:21  129.99           9.28
# 68942  2018-01-19 10:32:21  129.00          38.45
# 80847  2017-03-28 10:44:34  739.90          21.92
#
#                              customer_id  order_status  \
# 49672   f45ac6dfd34f67fc16e581fe9ae0028e             3
# 23948   d5b301a2087b017c4a9ca9730a2b18cf             3
# 105553  676ee955ce60a3b6eaa8c816cfb7fb04             3
# 68942   2f7319232811fe9879212e93efb30147             3
# 80847   374d1a370cc4fc67244345f046bbdff6             3
#
#        order_purchase_timestamp  ... product_height_cm product_width_cm  \
# 49672       2017-10-03 16:41:47  ...              11.0             28.0
# 23948       2017-11-12 11:43:17  ...              25.0             20.0
# 105553      2017-03-12 01:19:21  ...              40.0             30.0
# 68942       2018-01-09 19:34:58  ...              30.0             28.0
# 80847       2017-03-22 10:44:34  ...              32.0             27.0
#
#                       customer_unique_id customer_zip_code_prefix  \
# 49672   98407dc3f7283a8a678d1d97e139bce9                    71931
# 23948   45167dabf29a055f7c1208a69dc95586                     8210
# 105553  b21b70ecf581fa5addd602adc787d832                     8111
# 68942   adc2b0515dd6bea5e28161bbfeeade0e                    58045
# 80847   b4891a8e1c6726d478568eb2422dcce9                     6708
#
#         customer_geolocation_lat  customer_geolocation_lng  \
# 49672                 -15.836123                -48.040185
# 23948                 -23.532594                -46.442789
# 105553                -23.488042                -46.376701
# 68942                  -7.123182                -34.828699
# 80847                 -23.585222                -46.849074
#
#         seller_zip_code_prefix  seller_geolocation_lat  \
# 49672                    22240              -22.932957
# 23948                     3017              -23.533704
# 105553                    3426              -23.554792
# 68942                    13232              -23.209964
# 80847                    37795              -22.087304
#
#         seller_geolocation_lng  seller_customer_distance_km
# 49672               -43.187386                       938.81
# 23948               -46.612530                        17.30
# 105553              -46.531428                        17.43
# 68942               -46.776231                      2197.77
# 80847               -46.581748                       168.80
#
# [5 rows x 34 columns]

# %%
detailed_orders_data.isna().sum()
# Out:
# order_id                         0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# product_category_name            0
# product_name_lenght              0
# product_description_lenght       0
# product_photos_qty               0
# product_weight_g                 0
# product_length_cm                0
# product_height_cm                0
# product_width_cm                 0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_geolocation_lat         0
# customer_geolocation_lng         0
# seller_zip_code_prefix           0
# seller_geolocation_lat           0
# seller_geolocation_lng           0
# seller_customer_distance_km      0
# dtype: int64

# %%
detailed_orders_data.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value', 'customer_id',
#        'order_status', 'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'product_category_name',
#        'product_name_lenght', 'product_description_lenght',
#        'product_photos_qty', 'product_weight_g', 'product_length_cm',
#        'product_height_cm', 'product_width_cm', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_geolocation_lat',
#        'customer_geolocation_lng', 'seller_zip_code_prefix',
#        'seller_geolocation_lat', 'seller_geolocation_lng',
#        'seller_customer_distance_km'],
#       dtype='object')

# %%
detailed_orders_data.to_csv("data/fix/detailed_orders_dataset.csv", index=False)

# %% [markdown]
# # Seleksi Fitur

# %%
indices = np.arange(len(detailed_orders_data))

train_indices, temp_indices = train_test_split(indices, random_state=42, train_size=0.8)
test_indices, val_indices = train_test_split(temp_indices, random_state=42, train_size=0.5)

# %%
print(f"""
      train : {len(train_indices)} data
      test  : {len(test_indices)} data
      val   : {len(val_indices)} data
      """)
# Out:
#       train : 94080 data
#       test  : 11760 data
#       val   : 11761 data

# %%
def split_dataset(data: pd.DataFrame, y_columns: str):
    x_train_data = data.iloc[train_indices].drop(columns=[y_columns])
    x_test_data = data.iloc[test_indices].drop(columns=[y_columns])
    x_val_data = data.iloc[val_indices].drop(columns=[y_columns])

    y_train_data = data.iloc[train_indices][y_columns]
    y_test_data = data.iloc[test_indices][y_columns]
    y_val_data = data.iloc[val_indices][y_columns]

    return {"x":x_train_data, "y":y_train_data}, {"x":x_test_data, "y":y_test_data}, {"x":x_val_data, "y":y_val_data}

# %% [markdown]
# ## Prediksi Harga Barang

# %%
price_prediction = detailed_orders_data[['product_category_name','product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm', 'price']]
price_prediction.sample(5, random_state=42)
# Out:
#         product_category_name  product_weight_g  product_length_cm  \
# 49672                      71             733.0               29.0
# 23948                      71            1500.0               40.0
# 105553                     20            1500.0               50.0
# 68942                      68            6550.0               38.0
# 80847                      20            1925.0               30.0
#
#         product_height_cm  product_width_cm   price
# 49672                11.0              28.0  199.99
# 23948                25.0              20.0   89.90
# 105553               40.0              30.0  129.99
# 68942                30.0              28.0  129.00
# 80847                32.0              27.0  739.90

# %%
train_price_prediction, test_price_prediction, val_price_prediction = split_dataset(price_prediction, 'price')

# %% [markdown]
# ## Prediksi Barang Tiba

# %%
delivery_prediction = detailed_orders_data[['seller_customer_distance_km','price', 'freight_value','order_purchase_timestamp', 'order_delivered_customer_date','product_weight_g',"product_length_cm","product_height_cm", "product_width_cm"]]
delivery_prediction.sample(5, random_state=5)
# Out:
#         seller_customer_distance_km  price  freight_value  \
# 109165                       330.41   56.5          14.15
# 30066                        358.12  250.0          15.50
# 62798                        517.69  159.9          15.87
# 23260                        458.20   59.0          13.07
# 19194                        861.83  109.0          18.33
#
#        order_purchase_timestamp order_delivered_customer_date  \
# 109165      2018-01-19 08:02:06           2018-02-02 15:42:37
# 30066       2018-02-08 13:47:24           2018-02-28 19:22:49
# 62798       2018-01-18 22:48:53           2018-02-06 18:52:40
# 23260       2018-07-04 16:49:21           2018-07-07 14:41:18
# 19194       2017-11-02 11:10:32           2017-11-16 21:18:42
#
#         product_weight_g  product_length_cm  product_height_cm  \
# 109165             488.0               17.0               16.0
# 30066             7800.0               33.0               44.0
# 62798              500.0               35.0               45.0
# 23260              300.0               18.0                9.0
# 19194              800.0               24.0                6.0
#
#         product_width_cm
# 109165              17.0
# 30066               33.0
# 62798               15.0
# 23260               12.0
# 19194               24.0

# %%
delivery_prediction.dtypes
# Out:
# seller_customer_distance_km             float64
# price                                   float64
# freight_value                           float64
# order_purchase_timestamp         datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# product_weight_g                        float64
# product_length_cm                       float64
# product_height_cm                       float64
# product_width_cm                        float64
# dtype: object

# %%
delivery_prediction = delivery_prediction[~delivery_prediction['order_delivered_customer_date'].isna()]

delivery_prediction['order_estimated_delivery_day'] = (delivery_prediction["order_delivered_customer_date"] - delivery_prediction["order_purchase_timestamp"]).dt.days
delivery_prediction.drop(columns=["order_delivered_customer_date", "order_purchase_timestamp"], inplace=True)
delivery_prediction.sample(5, random_state=5)
# Out:
#         seller_customer_distance_km  price  freight_value  product_weight_g  \
# 109165                       330.41   56.5          14.15             488.0
# 30066                        358.12  250.0          15.50            7800.0
# 62798                        517.69  159.9          15.87             500.0
# 23260                        458.20   59.0          13.07             300.0
# 19194                        861.83  109.0          18.33             800.0
#
#         product_length_cm  product_height_cm  product_width_cm  \
# 109165               17.0               16.0              17.0
# 30066                33.0               44.0              33.0
# 62798                35.0               45.0              15.0
# 23260                18.0                9.0              12.0
# 19194                24.0                6.0              24.0
#
#         order_estimated_delivery_day
# 109165                            14
# 30066                             20
# 62798                             18
# 23260                              2
# 19194                             14

# %%
train_delivery_prediction, test_delivery_prediction, val_delivery_prediction = split_dataset(delivery_prediction, 'order_estimated_delivery_day')

# %% [markdown]
# # Save Dataset

# %%
np.savez_compressed("data/fix/price_prediction.npz", train=train_price_prediction, test=test_price_prediction, val=val_price_prediction)
np.savez_compressed("data/fix/delivery_prediction.npz", train=train_delivery_prediction, test=test_delivery_prediction, val=val_delivery_prediction)
